# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# **This is a Jupyter Notebook**

# %% [markdown]
# *My name is Nithish Kalyan . Im Interested in Data Science*

# %% [markdown]
# **The list of Data Science Languages are :**
# 1.Python
# 2.R
# 3.SQL

# %% [markdown]
# **The list of Data Science Libraries are :**
# NumPy. ...
# SciPy. ...
# Scikit-learn. ...
# TensorFlow. ...
# Keras. ...
# Matplotlib. ...
# Seaborn.

# %% [markdown]
# <table style="width:20%">
# # Data Science Tools
#
# | Category       | Tool          | Description                                                                 |
# |----------------|---------------|-----------------------------------------------------------------------------|
# | Programming    | Python        | A versatile language widely used in data science for its extensive libraries and ease of use. |
# | Programming    | R             | A language and environment specifically designed for statistical computing and graphics.      |
# | IDE/Notebook   | Jupyter       | An open-source web application for creating and sharing live code, equations, visualizations, and narrative text. |
# | IDE/Notebook   | RStudio       | An integrated development environment for R that provides tools to help you write and debug your code. |
# | Libraries      | Pandas        | A Python library for data manipulation and analysis, providing data structures and operations for manipulating numerical tables and time series. |
# | Libraries      | NumPy         | A fundamental package for scientific computing with Python, providing support for arrays, matrices, and many mathematical functions. |
# | Libraries      | SciPy         | A Python library used for scientific and technical computing.                                      |
# | Libraries      | Scikit-learn  | A machine learning library for Python, offering simple and efficient tools for data mining and data analysis. |
# | Libraries      | TensorFlow    | An open-source framework for machine learning and neural networks.                               |
# | Libraries      | Keras         | A high-level neural networks API, written in Python and capable of running on top of TensorFlow. |
# | Visualization  | Matplotlib    | A Python 2D plotting library which produces publication-quality figures.                          |
# | Visualization  | Seaborn       | A Python visualization library based on Matplotlib that provides a high-level interface for drawing attractive statistical graphics. |
# | Visualization  | Plotly        | An interactive graphing library for Python.                                                       |
# | Big Data       | Apache Hadoop | A framework that allows for the distributed processing of large data sets across clusters of computers. |
# | Big Data       | Apache Spark  | An open-source unified analytics engine for large-scale data processing, with built-in modules for streaming, SQL, machine learning, and graph processing. |
# | Databases      | MySQL         | An open-source relational database management system.                                             |
# | Databases      | PostgreSQL    | An advanced, open-source relational database management system.                                   |
# | Databases      | MongoDB       | A document-oriented NoSQL database used for high volume data storage.                             |
# | Cloud Services | AWS           | Amazon Web Services, a comprehensive and broadly adopted cloud platform.                          |
# | Cloud Services | GCP           | Google Cloud Platform, a suite of cloud computing services offered by Google.                     |
# | Cloud Services | Azure         | Microsoft Azure, a cloud computing service for building, testing, deploying, and managing applications and services. |
#
# </table>

# %%
#Arithmetic Expressions:
print(2+4-6*9)
# Out:
# -48

# %%
def multiply(a,b):
    return(a*b)
def add(a,b):
    return(a+b)
print(multiply(2,7))
print(add(9,1))
# Out:
# 14
# 10

# %%
# Function to convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example usage
minutes = 120  # You can change this value to test with different inputs
hours = minutes_to_hours(minutes)
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 120 minutes is equal to 2.0 hours.

# %% [markdown]
# ## Objectives:
# 1.To create Jupyter Notebook.
# 2.To Upload in Github

# %% [markdown]
# ## Author : Nithish kalyan
